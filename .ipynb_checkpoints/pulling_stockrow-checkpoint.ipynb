# %% [markdown]
# # Main for StockRow screener
# This notebook contains code to
# 1. Pull financial data from an external source
# 2. Lightly clean the data
# 3. Perform introductory financial analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import csv
import requests
import os
import time

# %%
stock_list = pd.read_csv('list_of_stocks.csv')
stock_list.head(2)
# Out:
#   Ticker            Name                  Sector Asset Class  \
# 0   AAPL       APPLE INC  Information Technology      Equity
# 1   MSFT  MICROSOFT CORP  Information Technology      Equity
#
#        Market Value  Weight (%)    Notional Value         Shares      CUSIP  \
# 0  1,875,566,056.60        4.85  1,875,566,056.60  14,040,770.00   37833100
# 1  1,709,995,853.92        4.42  1,709,995,853.92   6,717,457.00  594918104
#
#            ISIN    SEDOL   Price       Location Exchange Currency  FX Rate  \
# 0  US0378331005  2046251  133.58  United States   NASDAQ      USD        1
# 1  US5949181045  2588173  254.56  United States   NASDAQ      USD        1
#
#   Market Currency Accrual Date
# 0             USD           --
# 1             USD           --

# %%
# this function pulls Income Statement data from StockRow.com
    # based on the user's choice of ticker
# and outputs a DataFrame of the Income Statement

##### btw PLEASE visit stockrow.com #####
##### they made a wonderful resource ####

## also the 'meat' of this code comes from:
## https://www.kite.com/python/answers/how-to-download-a-csv-file-from-a-url-in-python

def income_puller(ticker):
    url=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=T&section=Income%20Statement&sort=desc'
    response = requests.get(url)
    with open(os.path.join("Income", f"{ticker}_inc.xlsx"), 'wb') as f:
        f.write(response.content)
    time.sleep(0.25)
    
    ticker_df = pd.read_excel(f'./Income/{ticker}_inc.xlsx').T
    # change the first row to the columns
    ticker_df.columns = ticker_df.iloc[0]
    #remove the first row
    ticker_df = ticker_df.iloc[1:]
    
    return ticker_df

# %%
# this function pulls Balance Sheet data from StockRow.com

def balance_puller(ticker):
    url=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=Q&section=Balance%20Sheet&sort=desc'
    response = requests.get(url)
    with open(os.path.join("BalanceSheet", f"{ticker}_balance.xlsx"), 'wb') as f:
        f.write(response.content)
    time.sleep(0.25)
    
    ticker_df = pd.read_excel(f'./BalanceSheet/{ticker}_balance.xlsx').T
    # change the first row to the columns
    ticker_df.columns = ticker_df.iloc[0]
    #remove the first row
    ticker_df = ticker_df.iloc[1:]
    
    return ticker_df

# %%
# this function pulls Cash Flow statement data from StockRow.com

def cashflow_puller(ticker):
    url=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=T&section=Cash%20Flow&sort=desc'
    response = requests.get(url)
    with open(os.path.join("CashFlow", f"{ticker}_cashflow.xlsx"), 'wb') as f:
        f.write(response.content)
    time.sleep(0.25)
    
    ticker_df = pd.read_excel(f'./CashFlow/{ticker}_cashflow.xlsx').T
    # change the first row to the columns
    ticker_df.columns = ticker_df.iloc[0]
    #remove the first row
    ticker_df = ticker_df.iloc[1:]
    
    return ticker_df

# %%
# this function prompts the user for a ticker input
# and calls the income_puller() function to return a DataFrame
# same for balance_puller() to return Balance Sheet info
def ticker_input():
    ticker = input('Please enter a ticker').upper()
    income_df = income_puller(ticker.upper())
    balance_df = balance_puller(ticker.upper())
    cashflow_df = cashflow_puller(ticker.upper())
    return income_df, balance_df, cashflow_df, ticker

# %%
# call the function and print charts
income_df,balance_df, cashflow_df, ticker = ticker_input()
ticker.upper()
# Out:
# Please enter a ticker SWKS
# 'SWKS'

# %%
# plot the charts I like most
sns.scatterplot(data=income_df,x=income_df.index,y='Revenue')
sns.scatterplot(data=income_df,x=income_df.index,y='EBITDA')
sns.scatterplot(data=income_df,x=income_df.index,y='Net Income Common')
sns.scatterplot(data=income_df,x=income_df.index,y='Gross Profit').set(xlabel='x',ylabel='y')
plt.legend(labels=['Revenue','EBITDA','Net Income','Gross Profit']);

# this code is optional, it may bounce errors
ticker_name = stock_list[stock_list['Ticker']==ticker]['Name'].to_string()
plt.title(f'Income Statement data for {ticker_name[5:]}');

# %%
sns.scatterplot(data=balance_df,x=balance_df.index,y="Cash and Short Term Investments", color='green')
sns.scatterplot(data=balance_df,x=balance_df.index,y="Total current assets", color='goldenrod')
sns.scatterplot(data=balance_df,x=balance_df.index,y="Total Assets", color='blue')
sns.scatterplot(data=balance_df,x=balance_df.index,y="Total current liabilities", color='crimson')
sns.scatterplot(data=balance_df,x=balance_df.index,y="Total liabilities",color='red')
plt.legend(labels=['Cash & Equivalents','Current Assets','Total Assets','Current Liabilities','Total Liabilities']);

# this code is optional, 
# it may bounce errors if the ticker isn't in stocks_list 
# try big familiar tickers like JNJ or INTC to calibrate 
ticker_name = stock_list[stock_list['Ticker']==ticker]['Name'].to_string()
plt.title(f'Balance Sheet data for {ticker_name[6:]}');

# %%
sns.scatterplot(data=cashflow_df,x=cashflow_df.index,y="Operating Cash Flow", color='blue')
sns.scatterplot(data=cashflow_df,x=cashflow_df.index,y=-cashflow_df["Capital expenditures"], color='red')
sns.scatterplot(data=cashflow_df,x=cashflow_df.index,y=-cashflow_df["Dividends Paid (Total)"], color='goldenrod')
sns.scatterplot(data=cashflow_df,x=cashflow_df.index,y=cashflow_df["Operating Cash Flow"]+cashflow_df["Capital expenditures"], color='green')
plt.legend(labels=['Operating Cash Flow','CapEx','Dividends','FCF (est)']);

# this code is optional, 
# it may bounce errors if the ticker isn't in stocks_list 
# try big familiar tickers like JNJ or INTC to calibrate 
ticker_name = stock_list[stock_list['Ticker']==ticker]['Name'].to_string()
plt.title(f'Cash Flow data for {ticker_name[5:]}');

# %% [markdown]
# ### I want to create code that pulls each financial statement into a DataFrame
# Each company should have three .xlsx files that were downloaded with the code above:
# - Income Statement
# - Balance Sheet
# - Cash Flow Statement
#
# Now I want to pull these financial tables into DataFrames

# %%
# I dropped some rows that give errors
drop_index_list = [7,84,309,486,340,636,754,1063,1352,1436,1481,1739,1756,1792,2044,2349,2793,2847,2947,2984,2995,3017,3026,3027,
                  3241,3352,3449,3450,3498,3499,3520,3560,3581,
                  3131,3326,3360,3361,3402,3431,3440,3468,3493,3496,3502,3537,3555,3608,3609,3611]

ticker_list = stock_list.drop(index=drop_index_list)['Ticker']

# %%
stock_list[stock_list['Ticker'] == 'ISSC'].index[0]
# Out:
# 2947

# %% [markdown]
# #### Creating dictionaries to call DataFrames

# %%
# this code creates empty dictionaries
# then loops to create DataFrames based on tickers and .xlsx files already downloaded
inc_dict = {}
bal_dict = {}
cfl_dict = {}

# income statement loop
for ticker in ticker_list:
    try:
        inc_dict[ticker] = pd.read_excel(f'./Income/{ticker}_inc.xlsx').T
    except:
        print(f'{ticker} is a bad Income Statement ticker')

# balance sheet loop
for ticker in ticker_list:
    try:
        bal_dict[ticker] = pd.read_excel(f'./BalanceSheet/{ticker}_bal.xlsx').T
    except:
        print(f'{ticker} is a bad Balance Sheet ticker')

# cash flow statement list
for ticker in ticker_list:
    try:
        cfl_dict[ticker] = pd.read_excel(f'./CashFlow/{ticker}_cashflow.xlsx').T
    except:
        print(f'{ticker} is a bad Cash Flow ticker')

# %%
bal_dict['AAPL']
# Out:
#                                                   0            1          2   \
# Unnamed: 0           Cash and Short Term Investments  Receivables  Inventory
# 2021-03-31 00:00:00                       6.9834e+10   3.3036e+10  4.943e+09
# 2020-12-31 00:00:00                       7.6826e+10    5.862e+10  4.023e+09
# 2020-09-30 00:00:00                       9.0979e+10   3.7445e+10  3.924e+09
# 2020-06-30 00:00:00                       9.3054e+10   3.2075e+10  3.289e+09
# 2020-03-31 00:00:00                       9.5128e+10   3.0677e+10  4.061e+09
# 2019-12-31 00:00:00                      1.07162e+11   3.9946e+10  4.097e+09
# 2019-09-30 00:00:00                      1.00557e+11   4.5804e+10  4.106e+09
# 2019-06-30 00:00:00                       9.4614e+10   2.6474e+10  3.355e+09
# 2019-03-31 00:00:00                       8.0092e+10   2.6278e+10  4.884e+09
# 2018-12-31 00:00:00                       8.6427e+10   3.6981e+10  4.988e+09
# 2018-09-30 00:00:00                       6.6301e+10   4.8995e+10  3.956e+09
# 2018-06-30 00:00:00                        7.097e+10   2.6367e+10  5.936e+09
# 2018-03-31 00:00:00                        8.794e+10   2.2408e+10  7.662e+09
# 2017-12-31 00:00:00                       7.7153e+10   5.0899e+10  4.421e+09
# 2017-09-30 00:00:00                       7.4181e+10   3.5673e+10  4.855e+09
# 2017-06-30 00:00:00                       7.6759e+10   2.2632e+10  3.146e+09
# 2017-03-31 00:00:00                       6.7101e+10   2.0612e+10   2.91e+09
# 2016-12-31 00:00:00                       6.0452e+10   2.7977e+10  2.712e+09
# 2016-09-30 00:00:00                       6.7155e+10   2.9299e+10  2.132e+09
# 2016-06-30 00:00:00                       6.1756e+10   1.9042e+10  1.831e+09
# 2016-03-31 00:00:00                       5.5283e+10   1.9824e+10  2.281e+09
# 2015-12-31 00:00:00                       3.8074e+10   2.4621e+10  2.451e+09
# 2015-09-30 00:00:00                       4.1601e+10   3.0343e+10  2.349e+09
# 2015-06-30 00:00:00                       3.4703e+10   1.9907e+10  2.042e+09
# 2015-03-31 00:00:00                       3.3096e+10   1.8164e+10  2.396e+09
# 2014-12-31 00:00:00                       3.2463e+10   2.9976e+10  2.283e+09
# 2014-09-30 00:00:00                       2.5077e+10   2.7219e+10  2.111e+09
# 2020-12-31 00:00:00  3.5217e+10  1.12043e+11
# 2020-09-30 00:00:00  3.1299e+10  1.22278e+11
# 2020-06-30 00:00:00  2.9132e+10  1.22186e+11
# 2020-03-31 00:00:00  2.3633e+10  1.18761e+11
# 2019-12-31 00:00:00    1.13e+09  1.08292e+11
# 2019-09-30 00:00:00    7.49e+09  1.08047e+11
# 2019-06-30 00:00:00  1.3804e+10  1.08418e+11
# 2019-03-31 00:00:00  3.2538e+10   1.1263e+11
# 2018-12-31 00:00:00  2.8303e+10   1.1473e+11
# 2018-09-30 00:00:00  4.8182e+10  1.14483e+11
# 2018-06-30 00:00:00   4.363e+10    1.146e+11
# 2018-03-31 00:00:00    3.39e+10   1.2184e+11
# 2017-12-31 00:00:00  4.5247e+10    1.224e+11
# 2017-09-30 00:00:00  4.1499e+10   1.1568e+11
# 2017-06-30 00:00:00   3.158e+10  1.08339e+11
# 2017-03-31 00:00:00  3.1421e+10   9.8522e+10
# 2016-12-31 00:00:00  2.7097e+10   8.7549e+10
# 2016-09-30 00:00:00  1.9877e+10   8.7032e+10
# 2016-06-30 00:00:00  2.3179e+10   8.4935e+10
# 2016-03-31 00:00:00  2.4589e+10   7.9872e+10
# 2015-12-31 00:00:00  2.4889e+10   6.2963e+10
# 2015-09-30 00:00:00  2.2727e+10   6.4328e+10
# 2015-06-30 00:00:00  1.9715e+10   5.4418e+10
# 2015-03-31 00:00:00  1.0775e+10   4.3871e+10
# 2014-12-31 00:00:00    3.94e+09   3.6403e+10
# 2014-09-30 00:00:00  1.0218e+10   3.5295e+10
# 2014-06-30 00:00:00  -6.765e+09    3.104e+10
# 2014-03-31 00:00:00 -2.4388e+10   1.6962e+10
# 2013-12-31 00:00:00  -2.375e+10   1.6961e+10
# 2013-09-30 00:00:00 -2.3586e+10    1.696e+10
# 2013-06-30 00:00:00 -2.5648e+10   1.6958e+10
# 2013-03-31 00:00:00 -3.9137e+10          NaN
# 2012-12-31 00:00:00  -3.982e+10          NaN
# 2012-09-30 00:00:00 -2.9129e+10          NaN
# 2012-06-30 00:00:00 -2.7654e+10          NaN
# 2012-03-31 00:00:00 -2.8538e+10          NaN
# 2011-12-31 00:00:00 -3.0156e+10          NaN
# 2011-09-30 00:00:00 -2.5952e+10          NaN
# 2011-06-30 00:00:00 -2.8395e+10          NaN
#
# [41 rows x 32 columns]

# %% [markdown]
# #### This bit of code sets the columns for each DataFrame inside its respective dictionary
#
# Specifically, the raw data is offset by one row, such that the 'columns' are a numbered range and the true variable names are in row 1. This code sets the columns to be the first row, then deletes the first row

# %%
bad_df_header_list = []
# income statement dataframes
for ticker in ticker_list:
    try:
        inc_dict[f"{ticker}"].columns = inc_dict[f"{ticker}"].iloc[0]
        inc_dict[f"{ticker}"] = inc_dict[f"{ticker}"].iloc[1:]
    except:
        print(f'{ticker} income statement did not work')
        bad_df_header_list.append(ticker)

# balance sheet dataframes
for ticker in ticker_list:
    try:
        bal_dict[f"{ticker}"].columns = bal_dict[f"{ticker}"].iloc[0]
        bal_dict[f"{ticker}"] = bal_dict[f"{ticker}"].iloc[1:]
    except:
        print(f'{ticker} balance sheet did not work')

# cash flow statement dataframes
for ticker in ticker_list:
    try:
        cfl_dict[f"{ticker}"].columns = cfl_dict[f"{ticker}"].iloc[0]
        cfl_dict[f"{ticker}"] = cfl_dict[f"{ticker}"].iloc[1:]
    except:
        print(f'{ticker} cash flow statement did not work')
# Out:
# QS income statement did not work
# MRVI income statement did not work
# PLTK income statement did not work
# SHC income statement did not work
# DNMR income statement did not work
# UPST income statement did not work
# MCFE income statement did not work
# AI income statement did not work
# PUBM income statement did not work
# SEER income statement did not work
# HYFM income statement did not work
# FDMT income statement did not work
# BCAB income statement did not work
# MAX income statement did not work
# SANA income statement did not work
# RSI income statement did not work
# GATO income statement did not work
# CGEM income statement did not work
# KRON income statement did not work
# KNTE income statement did not work
# ROOT income statement did not work
# PMVP income statement did not work
# GMTX income statement did not work
# BOLT income statement did not work
# OLMA income statement did not work
# SBTX income statement did not work
# MRVI cash flow statement did not work
# PLTK cash flow statement did not work
# UPST cash flow statement did not work
# MCFE cash flow statement did not work
# AI cash flow statement did not work
# PUBM cash flow statement did not work
# SEER cash flow statement did not work
# HYFM cash flow statement did not work
# FDMT cash flow statement did not work
# BCAB cash flow statement did not work
# MAX cash flow statement did not work
# SANA cash flow statement did not work
# RSI cash flow statement did not work
# GATO cash flow statement did not work
# CGEM cash flow statement did not work
# KNTE cash flow statement did not work
# ROOT cash flow statement did not work
# GMTX cash flow statement did not work
# BOLT cash flow statement did not work
# OLMA cash flow statement did not work
# SBTX cash flow statement did not work

# %%
#dropping some more bad tickers, as determined by the code above
another_drop_list = []
for ticker in bad_df_header_list:
    another_drop_list.append(ticker_list[ticker_list == ticker].index[0])

ticker_list.drop(index=another_drop_list,inplace=True)

# %%
ticker_list
# Out:
# 0        AAPL
# 1        MSFT
# 2        AMZN
# 3          FB
# 4       GOOGL
#         ...
# 3606     LIFE
# 3607     THMO
# 3610     HSTO
# 3612     VYNT
# 3613     PALI
# Name: Ticker, Length: 3539, dtype: object

# %% [markdown]
# #### This piece of code determines which financial data is similar across companies
# Should we use "EBIT" or "EBITDA" or "EBT" to compare metrics across companies? First let's determine, what are the most common metrics among DataFrames? We'll need a sort of logic table to help us count.
#
# I'm using AAPL and MSFT as calibration since they are two very large market caps, and they should have similarly-named data. The *intersection* between AAPL columns and MSFT columns will be the column headers for my new DataFrame.

# %%
inc_dict['AAPL']
# Out:
# Unnamed: 0               Revenue Cost of Revenue Gross Profit R&D Expenses  \
# 2021-03-31 00:00:00  3.25208e+11     1.98607e+11  1.26601e+11   2.0161e+10
# 2020-12-31 00:00:00  2.93971e+11     1.80236e+11  1.13735e+11   1.9464e+10
# 2020-09-30 00:00:00  2.74247e+11     1.69972e+11  1.04275e+11   1.8752e+10
# 2020-06-30 00:00:00  2.73621e+11     1.69627e+11  1.03994e+11   1.7884e+10
# 2020-03-31 00:00:00  2.68015e+11     1.65842e+11  1.02173e+11   1.7383e+10
# 2019-12-31 00:00:00  2.67683e+11     1.66105e+11  1.01578e+11   1.6766e+10
# 2012-06-30 00:00:00                   4.0133e+10        0.3753
# 2012-03-31 00:00:00                   3.8617e+10        0.3744
# 2011-12-31 00:00:00                   3.2982e+10        0.3558
# 2011-09-30 00:00:00                   2.5922e+10        0.3289
# 2011-06-30 00:00:00                   2.3607e+10        0.3202
#
# Unnamed: 0          Operating Cash Flow Margin
# 2021-03-31 00:00:00                     0.3062
# 2020-12-31 00:00:00                     0.3025
# 2020-09-30 00:00:00                     0.2942
# 2020-06-30 00:00:00                     0.2924
# 2020-03-31 00:00:00                     0.2812
# 2019-12-31 00:00:00                     0.2735
# 2019-09-30 00:00:00                     0.2667
# 2019-06-30 00:00:00                     0.2664
# 2019-03-31 00:00:00                      0.278
# 2018-12-31 00:00:00                     0.2899
# 2018-09-30 00:00:00                     0.2915
# 2018-06-30 00:00:00                     0.2886
# 2018-03-31 00:00:00                     0.2742
# 2017-12-31 00:00:00                      0.273
# 2017-09-30 00:00:00                     0.2802
# 2017-06-30 00:00:00                     0.2909
# 2017-03-31 00:00:00                     0.3038
# 2016-12-31 00:00:00                     0.3026
# 2016-09-30 00:00:00                     0.3071
# 2016-06-30 00:00:00                     0.2868
# 2016-03-31 00:00:00                     0.2968
# 2015-12-31 00:00:00                     0.3192
# 2015-09-30 00:00:00                     0.3477
# 2015-06-30 00:00:00                     0.3612
# 2015-03-31 00:00:00                     0.3597
# 2014-12-31 00:00:00                     0.3542
# 2014-09-30 00:00:00                     0.3267
# 2014-06-30 00:00:00                     0.3164
# 2014-03-31 00:00:00                     0.3064
# 2013-12-31 00:00:00                     0.3041
# 2013-09-30 00:00:00                      0.314
# 2013-06-30 00:00:00                     0.3122
# 2013-03-31 00:00:00                     0.3268
# 2012-12-31 00:00:00                     0.3445
# 2012-09-30 00:00:00                     0.3249
# 2012-06-30 00:00:00                     0.3504
# 2012-03-31 00:00:00                     0.3728
# 2011-12-31 00:00:00                     0.3544
# 2011-09-30 00:00:00                     0.3467
# 2011-06-30 00:00:00                     0.3268
#
# [40 rows x 28 columns]

# %% [markdown]
# ##### Start with Income Statement

# %%
AAPL_intersect_MSFT = set(inc_dict['AAPL'].columns).intersection(set(inc_dict['MSFT'].columns))

inc_df_list = pd.DataFrame(index=ticker_list, columns = list(AAPL_intersect_MSFT))


for i in inc_df_list.index:        # tickers
    for j in inc_df_list.columns:  # financial variables
        if j in inc_dict[i].columns:
            inc_df_list.loc[i,j] = True
        else:
            inc_df_list.loc[i,j] = False

inc_df_list
# Out:
#        EBITDA Revenue Gross Margin Gross Profit Operating Income  \
# Ticker
# AAPL     True    True         True         True             True
# MSFT     True    True         True         True             True
# AMZN     True    True         True         True             True
# FB       True    True         True         True             True
# GOOGL    True    True         True         True             True
# ...       ...     ...          ...          ...              ...
# LIFE     True    True         True         True             True
# THMO     True    True         True         True             True
# HSTO     True    True         True         True             True
# VYNT     True    True         True         True             True
# PALI     True    True         True         True             True
#
#        Consolidated Net Income/Loss Income Tax Provision Net Income Common  \
# Ticker
# AAPL                           True                 True              True
# MSFT                           True                 True              True
# AMZN                           True                 True              True
# FB                             True                 True              True
# GOOGL                          True                 True              True
# ...                             ...                  ...               ...
# LIFE                           True                False              True
# THMO                           True                False              True
# HSTO                           True                False              True
# VYNT                           True                 True              True
# PALI                           True                False              True
#
#        EPS (Basic, Consolidated) Income from Continuous Operations  ...  \
# Ticker                                                              ...
# AAPL                        True                              True  ...
# MSFT                        True                              True  ...
# AMZN                        True                              True  ...
# FB                          True                              True  ...
# GOOGL                       True                              True  ...
# ...                          ...                               ...  ...
# LIFE                        True                              True  ...
# THMO                        True                              True  ...
# HSTO                        True                              True  ...
# VYNT                        True                              True  ...
# PALI                        True                              True  ...
#
#        SG&A Expenses EBT margin EBITDA Margin Operating Cash Flow Margin  \
# Ticker
# AAPL            True       True          True                       True
# MSFT            True       True          True                       True
# AMZN            True       True          True                       True
# FB              True       True          True                       True
# GOOGL           True       True          True                       True
# ...              ...        ...           ...                        ...
# LIFE            True       True          True                       True
# THMO            True       True          True                       True
# HSTO            True       True          True                       True
# VYNT            True       True          True                       True
# PALI            True       True          True                       True
#
#        EPS (Basic) Income after Tax   EBT  EBIT Free Cash Flow Margin  \
# Ticker
# AAPL          True             True  True  True                  True
# MSFT          True             True  True  True                  True
# AMZN          True             True  True  True                  True
# FB            True             True  True  True                  True
# GOOGL         True             True  True  True                  True
# ...            ...              ...   ...   ...                   ...
# LIFE          True             True  True  True                  True
# THMO          True             True  True  True                  True
# HSTO          True             True  True  True                  True
# VYNT          True             True  True  True                  True
# PALI          True             True  True  True                  True
#
#        Interest Expense (Operating)
# Ticker
# AAPL                           True
# MSFT                           True
# AMZN                           True
# FB                            False
# GOOGL                          True
# ...                             ...
# LIFE                          False
# THMO                           True
# HSTO                          False
# VYNT                           True
# PALI                           True
#
# [3539 rows x 28 columns]

# %%
inc_df_list.sum()
# Out:
# EBITDA                               3142.0
# Revenue                              3357.0
# Gross Margin                         3470.0
# Gross Profit                         3460.0
# Operating Income                     3465.0
# Consolidated Net Income/Loss         3517.0
# Income Tax Provision                 3096.0
# Net Income Common                    3517.0
# EPS (Basic, Consolidated)            3459.0
# Income from Continuous Operations    3468.0
# Net Profit Margin                    3517.0
# R&D Expenses                         1450.0
# EBIT Margin                          3505.0
# EPS (Diluted, from Cont. Ops)        3459.0
# Non-operating Interest Expenses      2869.0
# Non-operating Income/Expense         3277.0
# Cost of Revenue                      3247.0
# EPS (Basic, from Continuous Ops)     3459.0
# SG&A Expenses                        3441.0
# EBT margin                           3519.0
# EBITDA Margin                        3514.0
# Operating Cash Flow Margin           3533.0
# EPS (Basic)                          3505.0
# Income after Tax                     3465.0
# EBT                                  3518.0
# EBIT                                 3106.0
# Free Cash Flow Margin                3533.0
# Interest Expense (Operating)         2135.0
# dtype: float64

# %% [markdown]
# ##### Same for Balance Sheet

# %%
AAPL_intersect_MSFT = set(bal_dict['AAPL'].columns).intersection(set(bal_dict['MSFT'].columns))

bal_df_list = pd.DataFrame(index=ticker_list, columns = list(AAPL_intersect_MSFT))


for i in bal_df_list.index:        # tickers
    for j in bal_df_list.columns:  # financial variables
        if j in bal_dict[i].columns:
            bal_df_list.loc[i,j] = True
        else:
            bal_df_list.loc[i,j] = False

bal_df_list
# Out:
#        Retained Earnings Non-current Liabilities (Other) Accrued Expenses  \
# Ticker
# AAPL                True                            True             True
# MSFT                True                            True             True
# AMZN                True                            True             True
# FB                  True                            True             True
# GOOGL               True                            True             True
# ...                  ...                             ...              ...
# LIFE                True                            True             True
# THMO                True                            True             True
# HSTO                True                            True             True
# VYNT                True                            True            False
# PALI                True                            True             True
#
#        Non-current Revenue (Deferred) Total current assets  \
# Ticker
# AAPL                             True                 True
# MSFT                             True                 True
# AMZN                             True                 True
# FB                              False                 True
# GOOGL                            True                 True
# ...                               ...                  ...
# LIFE                             True                 True
# THMO                             True                 True
# HSTO                             True                 True
# VYNT                             True                 True
# PALI                            False                 True
#
#        Total current liabilities Common Equity (Total) Current Part of Debt  \
# Ticker
# AAPL                        True                  True                 True
# MSFT                        True                  True                 True
# AMZN                        True                  True                 True
# FB                          True                  True                 True
# GOOGL                       True                  True                 True
# ...                          ...                   ...                  ...
# LIFE                        True                  True                 True
# THMO                        True                  True                 True
# HSTO                        True                  True                 True
# VYNT                        True                  True                 True
# PALI                        True                  True                 True
#
#        Total liabilities Common Stock (Net)  ... Long Term Debt (Total)  \
# Ticker                                       ...
# AAPL                True               True  ...                   True
# MSFT                True               True  ...                   True
# AMZN                True               True  ...                   True
# FB                  True               True  ...                   True
# GOOGL               True               True  ...                   True
# ...                  ...                ...  ...                    ...
# LIFE                True               True  ...                   True
# THMO                True               True  ...                   True
# HSTO                True               True  ...                   True
# VYNT                True               True  ...                   True
# PALI                True               True  ...                   True
#
#        Other current assets Goodwill and Intangible Assets (Total)  \
# Ticker
# AAPL                   True                                   True
# MSFT                   True                                   True
# AMZN                  False                                   True
# FB                     True                                   True
# GOOGL                  True                                   True
# ...                     ...                                    ...
# LIFE                   True                                   True
# THMO                   True                                   True
# HSTO                   True                                   True
# VYNT                   True                                   True
# PALI                   True                                   True
#
#        Total non-current liabilities Total Debt  \
# Ticker
# AAPL                            True       True
# MSFT                            True       True
# AMZN                            True       True
# FB                              True       True
# GOOGL                           True       True
# ...                              ...        ...
# LIFE                            True       True
# THMO                            True       True
# HSTO                            True       True
# VYNT                            True       True
# PALI                            True       True
#
#        Shareholders Equity (Tangible) Inventory Shareholders Equity (Total)  \
# Ticker
# AAPL                             True      True                        True
# MSFT                             True      True                        True
# AMZN                             True      True                        True
# FB                               True     False                        True
# GOOGL                            True      True                        True
# ...                               ...       ...                         ...
# LIFE                             True     False                        True
# THMO                             True      True                        True
# HSTO                             True      True                        True
# VYNT                             True     False                        True
# PALI                             True     False                        True
#
#        Accounts Payable Long-Term Investments
# Ticker
# AAPL               True                  True
# MSFT               True                  True
# AMZN               True                  True
# FB                 True                  True
# GOOGL              True                  True
# ...                 ...                   ...
# LIFE               True                  True
# THMO               True                 False
# HSTO               True                  True
# VYNT               True                  True
# PALI               True                 False
#
# [3539 rows x 32 columns]

# %%
bal_df_list.sum()
# Out:
# Retained Earnings                              3528.0
# Non-current Liabilities (Other)                3504.0
# Accrued Expenses                               2866.0
# Non-current Revenue (Deferred)                 2005.0
# Total current assets                           3529.0
# Total current liabilities                      3527.0
# Common Equity (Total)                          3534.0
# Current Part of Debt                           3394.0
# Total liabilities                              3534.0
# Common Stock (Net)                             3506.0
# Total Assets                                   3537.0
# Total non-current assets                       3514.0
# Long Term Tax Liability (Deferred)             2492.0
# Receivables                                    3034.0
# Other current liabilities                      2857.0
# Current Revenue (Deferred)                     1253.0
# Long-term assets (Other)                       3510.0
# Cash and Short Term Investments                3530.0
# Shares (Common)                                3500.0
# Net Debt                                       3534.0
# Property, Plant, Equpment (Net)                3492.0
# Shareholders Equity and Liabilities (Total)    3516.0
# Long Term Debt (Total)                         3476.0
# Other current assets                           2780.0
# Goodwill and Intangible Assets (Total)         3273.0
# Total non-current liabilities                  3512.0
# Total Debt                                     3492.0
# Shareholders Equity (Tangible)                 3516.0
# Inventory                                      2002.0
# Shareholders Equity (Total)                    3534.0
# Accounts Payable                               3492.0
# Long-Term Investments                          2401.0
# dtype: float64

# %%
bal_dict['AAPL'].iloc[3]
# Out:
# Unnamed: 0
# Cash and Short Term Investments                 9.3054e+10
# Receivables                                     3.2075e+10
# Inventory                                        3.289e+09
# Other current assets                            1.0958e+10
# Total current assets                           1.40065e+11
# Property, Plant, Equpment (Net)                 4.3851e+10
# Long-Term Investments                          1.02219e+11
# Goodwill and Intangible Assets (Total)                 NaN
# Long-term assets (Other)                        3.1209e+10
# Total non-current assets                       1.77279e+11
# Total Assets                                   3.17344e+11
# Accounts Payable                                3.8058e+10
# Accrued Expenses                                       NaN
# Current Part of Debt                            2.0048e+10
# Current Revenue (Deferred)                       6.313e+09
# Other current liabilities                       3.9945e+10
# Total current liabilities                       9.5318e+10
# Long Term Debt (Total)                         1.02138e+11
# Non-current Revenue (Deferred)                         NaN
# Long Term Tax Liability (Deferred)                8.33e+08
# Non-current Liabilities (Other)                 4.7606e+10
# Total non-current liabilities                  1.49744e+11
# Total liabilities                              2.45062e+11
# Common Stock (Net)                              4.8696e+10
# Retained Earnings                               2.4136e+10
# Common Equity (Total)                           7.2282e+10
# Shareholders Equity (Total)                     7.2282e+10
# Shareholders Equity and Liabilities (Total)    3.17344e+11
# Shares (Common)                                1.71358e+10
# Shareholders Equity (Tangible)                  7.2282e+10
# Net Debt                                        2.9132e+10
# Total Debt                                     1.22186e+11
# Name: 2020-06-30 00:00:00, dtype: object

# %% [markdown]
# ##### Same for Cash Flow Statement

# %%
AAPL_intersect_MSFT = set(cfl_dict['AAPL'].columns).intersection(set(cfl_dict['MSFT'].columns))

cfl_df_list = pd.DataFrame(index=ticker_list, columns = list(AAPL_intersect_MSFT))


for i in cfl_df_list.index:        # tickers
    for j in cfl_df_list.columns:  # financial variables
        if j in cfl_dict[i].columns:
            cfl_df_list.loc[i,j] = True
        else:
            cfl_df_list.loc[i,j] = False

cfl_df_list
# Out:
#        Dividends Paid (Common) Capital Stock Change Net Aquisitions  \
# Ticker
# AAPL                      True                 True            True
# MSFT                      True                 True            True
# AMZN                      True                 True            True
# FB                        True                 True            True
# GOOGL                     True                 True            True
# ...                        ...                  ...             ...
# LIFE                      True                 True           False
# THMO                      True                 True            True
# HSTO                      True                 True            True
# VYNT                      True                 True            True
# PALI                      True                 True           False
#
#        Beginning Cash Stock Based Compensation Dividends Paid (Total)  \
# Ticker
# AAPL             True                     True                   True
# MSFT             True                     True                   True
# AMZN             True                     True                  False
# FB               True                     True                  False
# GOOGL            True                     True                  False
# ...               ...                      ...                    ...
# LIFE             True                     True                  False
# THMO             True                     True                  False
# HSTO             True                     True                  False
# VYNT             True                     True                  False
# PALI             True                     True                  False
#
#        Depreciation & Amortization Capital expenditures  \
# Ticker
# AAPL                          True                 True
# MSFT                          True                 True
# AMZN                          True                 True
# FB                            True                 True
# GOOGL                         True                 True
# ...                            ...                  ...
# LIFE                          True                 True
# THMO                          True                 True
# HSTO                          True                 True
# VYNT                          True                 True
# PALI                          True                 True
#
#        Assets Liabilities Change (Total) Non Cash Items (Other)  ...  \
# Ticker                                                           ...
# AAPL                                True                   True  ...
# MSFT                                True                   True  ...
# AMZN                                True                   True  ...
# FB                                  True                   True  ...
# GOOGL                               True                   True  ...
# ...                                  ...                    ...  ...
# LIFE                                True                   True  ...
# THMO                                True                   True  ...
# HSTO                                True                   True  ...
# VYNT                                True                   True  ...
# PALI                                True                   True  ...
#
#        Change in other assets and liabilities Net Income Investing cash flow  \
# Ticker
# AAPL                                     True       True                True
# MSFT                                     True       True                True
# AMZN                                     True       True                True
# FB                                       True       True                True
# GOOGL                                    True       True                True
# ...                                       ...        ...                 ...
# LIFE                                     True       True                True
# THMO                                     True       True                True
# HSTO                                     True       True                True
# VYNT                                     True       True                True
# PALI                                     True       True                True
#
#        Equity Repurchase (Common, Net) Other financial activities  \
# Ticker
# AAPL                              True                       True
# MSFT                              True                       True
# AMZN                              True                       True
# FB                                True                       True
# GOOGL                             True                       True
# ...                                ...                        ...
# LIFE                              True                       True
# THMO                              True                       True
# HSTO                              True                       True
# VYNT                              True                       True
# PALI                              True                       True
#
#        Long-Term Investments Change (Net) Accounts Payable Change  \
# Ticker
# AAPL                                 True                    True
# MSFT                                 True                    True
# AMZN                                 True                    True
# FB                                   True                    True
# GOOGL                                True                    True
# ...                                   ...                     ...
# LIFE                                False                   False
# THMO                                False                    True
# HSTO                                False                   False
# VYNT                                False                   False
# PALI                                False                   False
#
#        Operating Cash Flow Financing cash flow Ending Cash
# Ticker
# AAPL                  True                True        True
# MSFT                  True                True        True
# AMZN                  True                True        True
# FB                    True                True        True
# GOOGL                 True                True        True
# ...                    ...                 ...         ...
# LIFE                  True                True        True
# THMO                  True                True        True
# HSTO                  True                True        True
# VYNT                  True                True        True
# PALI                  True                True        True
#
# [3539 rows x 28 columns]

# %%
cfl_df_list.sum()
# Out:
# Dividends Paid (Common)                     3525.0
# Capital Stock Change                        3368.0
# Net Aquisitions                             2459.0
# Beginning Cash                              3485.0
# Stock Based Compensation                    3161.0
# Dividends Paid (Total)                      2098.0
# Depreciation & Amortization                 3479.0
# Capital expenditures                        3411.0
# Assets Liabilities Change (Total)           3491.0
# Non Cash Items (Other)                      3458.0
# Accounts Receivable Change                  3184.0
# Investments Change (Net)                    2631.0
# Change in inventories                       1995.0
# Repayment/Issuance of Debt (Net)            3371.0
# Other investing activities                  2947.0
# Issuance/Purchase of Shares                 3430.0
# Change in payables and accrued liability    3088.0
# Change in Cash                              3520.0
# Change in other assets and liabilities      3442.0
# Net Income                                  3537.0
# Investing cash flow                         3513.0
# Equity Repurchase (Common, Net)             3363.0
# Other financial activities                  3473.0
# Long-Term Investments Change (Net)          1938.0
# Accounts Payable Change                     2205.0
# Operating Cash Flow                         3520.0
# Financing cash flow                         3513.0
# Ending Cash                                 3490.0
# dtype: float64

# %% [markdown]
# ##### Columns to keep

# %%
inc_columns = ['Revenue','Gross Profit','Operating Income','Income Tax Provision', 'Net Income Common']
bal_columns = ['Total Assets','Total current assets','Total liabilities','Total current liabilities',
               'Shareholders Equity (Total)','Shares (Common)']
cfl_columns = ['Dividends Paid (Common)','Capital expenditures','Operating Cash Flow','Equity Repurchase (Common, Net)']

# %% [markdown]
# ##### Applying the 'keep' columns to each DF inside the DF dictionaries
# Using AAPL as an example

# %%
inc_dict['AAPL'][inc_columns].head(2)
# Out:
# Unnamed: 0               Revenue Gross Profit Operating Income  \
# 2021-03-31 00:00:00  3.25208e+11  1.26601e+11       8.8903e+10
# 2020-12-31 00:00:00  2.93971e+11  1.13735e+11       7.4253e+10
#
# Unnamed: 0          Income Tax Provision Net Income Common
# 2021-03-31 00:00:00           1.3317e+10        7.6311e+10
# 2020-12-31 00:00:00           1.0822e+10         6.393e+10

# %%
bal_dict['AAPL'][bal_columns].head(2)
# Out:
# Unnamed: 0          Total Assets Total current assets Total liabilities  \
# 2021-03-31 00:00:00  3.37158e+11          1.21465e+11        2.6798e+11
# 2020-12-31 00:00:00  3.54054e+11          1.54106e+11        2.8783e+11
#
# Unnamed: 0          Total current liabilities Shareholders Equity (Total)  \
# 2021-03-31 00:00:00               1.06385e+11                  6.9178e+10
# 2020-12-31 00:00:00               1.32507e+11                  6.6224e+10
#
# Unnamed: 0          Shares (Common)
# 2021-03-31 00:00:00     1.66863e+10
# 2020-12-31 00:00:00     1.68233e+10

# %%
cfl_dict['AAPL'][cfl_columns].head(2)
# Out:
# Unnamed: 0          Dividends Paid (Common) Capital expenditures  \
# 2021-03-31 00:00:00             -1.4227e+10           -9.118e+09
# 2020-12-31 00:00:00             -1.4155e+10           -8.702e+09
#
# Unnamed: 0          Operating Cash Flow Equity Repurchase (Common, Net)
# 2021-03-31 00:00:00          9.9591e+10                      -7.539e+10
# 2020-12-31 00:00:00          8.8921e+10                     -7.5549e+10

# %% [markdown]
# ##### Combining the three separate DataFrames above into one large DataFrame

# %%
#still using AAPL as one example
pd.concat([inc_dict['AAPL'][inc_columns],bal_dict['AAPL'][bal_columns],cfl_dict['AAPL'][cfl_columns]], axis=1).head(2)
# Out:
# Unnamed: 0               Revenue Gross Profit Operating Income  \
# 2021-03-31 00:00:00  3.25208e+11  1.26601e+11       8.8903e+10
# 2020-12-31 00:00:00  2.93971e+11  1.13735e+11       7.4253e+10
#
# Unnamed: 0          Income Tax Provision Net Income Common Total Assets  \
# 2021-03-31 00:00:00           1.3317e+10        7.6311e+10  3.37158e+11
# 2020-12-31 00:00:00           1.0822e+10         6.393e+10  3.54054e+11
#
# Unnamed: 0          Total current assets Total liabilities  \
# 2021-03-31 00:00:00          1.21465e+11        2.6798e+11
# 2020-12-31 00:00:00          1.54106e+11        2.8783e+11
#
# Unnamed: 0          Total current liabilities Shareholders Equity (Total)  \
# 2021-03-31 00:00:00               1.06385e+11                  6.9178e+10
# 2020-12-31 00:00:00               1.32507e+11                  6.6224e+10
#
# Unnamed: 0          Shares (Common) Dividends Paid (Common)  \
# 2021-03-31 00:00:00     1.66863e+10             -1.4227e+10
# 2020-12-31 00:00:00     1.68233e+10             -1.4155e+10
#
# Unnamed: 0          Capital expenditures Operating Cash Flow  \
# 2021-03-31 00:00:00           -9.118e+09          9.9591e+10
# 2020-12-31 00:00:00           -8.702e+09          8.8921e+10
#
# Unnamed: 0          Equity Repurchase (Common, Net)
# 2021-03-31 00:00:00                      -7.539e+10
# 2020-12-31 00:00:00                     -7.5549e+10

# %% [markdown]
# ##### This code snippet takes the above line and applies it to *every* DataFrame in our separated DataFrame dictionaries above
# There's also a "try / except" applied because many of the DFs will throw errors. Such 'bad' tickers are appended to a separate list; we may revisit them

# %%
full_df_dict = {}
bad_tickers = []
for ticker in ticker_list:
    try:
        full_df_dict[ticker] = pd.concat([inc_dict[ticker][inc_columns],bal_dict[ticker][bal_columns],cfl_dict[ticker][cfl_columns]], axis=1)
        full_df_dict[ticker]['Ticker'] = ticker
    except:
        print(f"{ticker} threw an error")
        bad_tickers.append(ticker)
# Out:
# JPM threw an error
# WFC threw an error
# USB threw an error
# PNC threw an error
# CB threw an error
# MET threw an error
# PSA threw an error
# AIG threw an error
# PRU threw an error
# CARR threw an error
# AFL threw an error
# OTIS threw an error
# PEG threw an error
# KHC threw an error
# FTV threw an error
# SYF threw an error
# ARE threw an error
# INVH threw an error
# ALLY threw an error
# RCL threw an error
# ESS threw an error
# SGEN threw an error
# AVTR threw an error
# BXP threw an error
# SNOW threw an error
# EQH threw an error
# ABNB threw an error
# NLY threw an error
# LNC threw an error
# ELS threw an error
# PLTR threw an error
# RE threw an error
# AMH threw an error
# AGNC threw an error
# RNR threw an error
# CUBE threw an error
# TW threw an error
# LSXMK threw an error
# FRT threw an error
# FATE threw an error
# RGLD threw an error
# REXR threw an error
# OPEN threw an error
# LSI threw an error
# RDFN threw an error
# KRC threw an error
# AIRC threw an error
# CNXC threw an error
# BRX threw an error
# EGP threw an error
# CHWY threw an error
# ORI threw an error
# PACB threw an error
# SLM threw an error
# DASH threw an error
# DEI threw an error
# STAG threw an error
# VNT threw an error
# BPMC threw an error
# SLG threw an error
# BBIO threw an error
# ADNT threw an error
# CHNG threw an error
# BXMT threw an error
# TGTX threw an error
# OMF threw an error
# HIW threw an error
# CDLX threw an error
# COIN threw an error
# FTDR threw an error
# HR threw an error
# LAZR threw an error
# SKLZ threw an error
# IIPR threw an error
# IOVA threw an error
# TRNO threw an error
# NRZ threw an error
# BHF threw an error
# HPP threw an error
# DOC threw an error
# SAGE threw an error
# EBC threw an error
# WMG threw an error
# ADC threw an error
# CHX threw an error
# ALLK threw an error
# ARNA threw an error
# VCYT threw an error
# KOD threw an error
# FOUR threw an error
# ESGR threw an error
# RPRX threw an error
# VCEL threw an error
# TPTX threw an error
# APG threw an error
# PSB threw an error
# CNO threw an error
# NHI threw an error
# LTHM threw an error
# ARRY threw an error
# BMBL threw an error
# MVIS threw an error
# FLOW threw an error
# AGO threw an error
# ARNC threw an error
# EDIT threw an error
# MGEE threw an error
# SHLS threw an error
# PDM threw an error
# NAVI threw an error
# CIM threw an error
# CCXI threw an error
# CMP threw an error
# NOVA threw an error
# GBT threw an error
# FRME threw an error
# MFA threw an error
# ARVN threw an error
# APLS threw an error
# RKT threw an error
# MGNX threw an error
# WRE threw an error
# KRTX threw an error
# MNR threw an error
# GNW threw an error
# XM threw an error
# SILK threw an error
# ROIC threw an error
# ALLO threw an error
# IHRT threw an error
# SI threw an error
# LILAK threw an error
# BEAM threw an error
# LESL threw an error
# BCRX threw an error
# FSR threw an error
# MPLN threw an error
# MP threw an error
# GRWG threw an error
# RVNC threw an error
# DCPH threw an error
# SWTX threw an error
# OCGN threw an error
# KRYS threw an error
# KURA threw an error
# RCKT threw an error
# IRT threw an error
# CDMO threw an error
# SKT threw an error
# AXNX threw an error
# COKE threw an error
# DM threw an error
# DRNA threw an error
# SPT threw an error
# AXSM threw an error
# CELH threw an error
# XPEL threw an error
# RCUS threw an error
# MSGE threw an error
# GDRX threw an error
# OCDX threw an error
# LTC threw an error
# CVM threw an error
# SAVA threw an error
# HRTX threw an error
# VUZI threw an error
# DEA threw an error
# CLI threw an error
# AAT threw an error
# WLL threw an error
# GEVO threw an error
# REYN threw an error
# GTY threw an error
# BLNK threw an error
# ETWO threw an error
# ADV threw an error
# DMTK threw an error
# GOEV threw an error
# ATRA threw an error
# RPAI threw an error
# BRP threw an error
# IMGN threw an error
# OCUL threw an error
# AVXL threw an error
# WOOF threw an error
# WKHS threw an error
# CNDT threw an error
# RWT threw an error
# MCRB threw an error
# ALGM threw an error
# MRSN threw an error
# SIBN threw an error
# MDGL threw an error
# CLOV threw an error
# UTZ threw an error
# ZOM threw an error
# AAN threw an error
# ALDX threw an error
# GOOD threw an error
# AFIN threw an error
# DNOW threw an error
# CRIS threw an error
# RUBY threw an error
# APPH threw an error
# NARI threw an error
# TLS threw an error
# RIDE threw an error
# ANAT threw an error
# CHCT threw an error
# REPL threw an error
# CSTL threw an error
# ASO threw an error
# ONEW threw an error
# RDUS threw an error
# BATRK threw an error
# OMER threw an error
# BTRS threw an error
# AMWL threw an error
# CERT threw an error
# HYLN threw an error
# KROS threw an error
# ADVM threw an error
# SESN threw an error
# DRVN threw an error
# NXRT threw an error
# CCO threw an error
# RADI threw an error
# HMN threw an error
# GBIO threw an error
# ALEC threw an error
# PRCH threw an error
# ARKO threw an error
# YMAB threw an error
# TCRR threw an error
# SENS threw an error
# KIDS threw an error
# RYTM threw an error
# WMK threw an error
# UHT threw an error
# OM threw an error
# SGFY threw an error
# SAFE threw an error
# ASAN threw an error
# EAR threw an error
# OCX threw an error
# GCMG threw an error
# MASS threw an error
# GNUS threw an error
# IMVT threw an error
# MYOV threw an error
# FREE threw an error
# CELC threw an error
# SFT threw an error
# GPMT threw an error
# AXGN threw an error
# STEP threw an error
# HIMS threw an error
# EGLE threw an error
# ARQT threw an error
# DVAX threw an error
# ORC threw an error
# DTIL threw an error
# RMO threw an error
# SNDX threw an error
# LOTZ threw an error
# ADN threw an error
# GMRE threw an error
# BNL threw an error
# UWMC threw an error
# CDXC threw an error
# ARR threw an error
# ACRS threw an error
# LUNG threw an error
# HSII threw an error
# LORL threw an error
# IVR threw an error
# AMBC threw an error
# CLNC threw an error
# EVLO threw an error
# LILA threw an error
# WISH threw an error
# GNOG threw an error
# STTK threw an error
# CERE threw an error
# LODE threw an error
# ONTF threw an error
# NUVB threw an error
# SELB threw an error
# CRSR threw an error
# MILE threw an error
# TTCF threw an error
# MSP threw an error
# CIO threw an error
# ESPR threw an error
# ZNTL threw an error
# PLRX threw an error
# NKTX threw an error
# RLAY threw an error
# STOK threw an error
# IBIO threw an error
# KELYA threw an error
# CATC threw an error
# PLYM threw an error
# XL threw an error
# GOCO threw an error
# CCCC threw an error
# AGEN threw an error
# CMRX threw an error
# VERX threw an error
# AKTS threw an error
# NLTX threw an error
# SRRK threw an error
# PAYA threw an error
# UMH threw an error
# AQB threw an error
# TNXP threw an error
# VOR threw an error
# GOSS threw an error
# XENT threw an error
# VAPO threw an error
# ALXO threw an error
# BLFS threw an error
# PTVE threw an error
# AKRO threw an error
# INTZ threw an error
# VLDR threw an error
# BOMN threw an error
# BCEL threw an error
# BLI threw an error
# SUMO threw an error
# AMAL threw an error
# GERN threw an error
# XXII threw an error
# APTS threw an error
# ANNX threw an error
# ATRS threw an error
# CRTX threw an error
# IGMS threw an error
# GTHX threw an error
# DSP threw an error
# EVER threw an error
# PRAX threw an error
# EOSE threw an error
# KYMR threw an error
# OPRX threw an error
# ICPT threw an error
# VKTX threw an error
# AMPE threw an error
# RCEL threw an error
# ATHA threw an error
# ALX threw an error
# BPRN threw an error
# PAE threw an error
# AVRO threw an error
# AMTI threw an error
# RNA threw an error
# ZIOP threw an error
# TRCH threw an error
# SRG threw an error
# CNST threw an error
# RLMD threw an error
# TITN threw an error
# GDP threw an error
# NEXT threw an error
# BDTX threw an error
# AAIC threw an error
# KNSA threw an error
# PROS threw an error
# SYRS threw an error
# CRNX threw an error
# PHAT threw an error
# XCUR threw an error
# STRO threw an error
# PRLD threw an error
# LE threw an error
# MRNS threw an error
# OLP threw an error
# ORIC threw an error
# CTT threw an error
# BTAI threw an error
# HGEN threw an error
# PASG threw an error
# BFS threw an error
# STIM threw an error
# CMO threw an error
# TYME threw an error
# KALA threw an error
# VRAY threw an error
# RVI threw an error
# VSEC threw an error
# IHC threw an error
# KALV threw an error
# CRDF threw an error
# ASPN threw an error
# CLPR threw an error
# HOFT threw an error
# PCVX threw an error
# ARLO threw an error
# AOUT threw an error
# AVIR threw an error
# FLMN threw an error
# DLTH threw an error
# MBIO threw an error
# DSSI threw an error
# DX threw an error
# CODX threw an error
# WTI threw an error
# ALTM threw an error
# SCPL threw an error
# SRTS threw an error
# ATOM threw an error
# CBAY threw an error
# PBYI threw an error
# MRKR threw an error
# ENOB threw an error
# AFIB threw an error
# PRVB threw an error
# UBA threw an error
# UG threw an error
# VNTR threw an error
# STXS threw an error
# CWBR threw an error
# OPTN threw an error
# LPG threw an error
# MGTA threw an error
# VSTM threw an error
# MTNB threw an error
# HFFG threw an error
# ALVR threw an error
# WTER threw an error
# CLPT threw an error
# DRRX threw an error
# KZR threw an error
# CLXT threw an error
# TXMD threw an error
# BRG threw an error
# JAX threw an error
# FIXX threw an error
# FUV threw an error
# ARPO threw an error
# HYRE threw an error
# ETNB threw an error
# HBT threw an error
# AWH threw an error
# HARP threw an error
# CARE threw an error
# CDR threw an error
# FONR threw an error
# GBL threw an error
# GALT threw an error
# PHAS threw an error
# NXTC threw an error
# PRTK threw an error
# OPRT threw an error
# PVAC threw an error
# FSTX threw an error
# CRBP threw an error
# CKPT threw an error
# EVOK threw an error
# OYST threw an error
# SAMG threw an error
# TCDA threw an error
# FBRX threw an error
# IDYA threw an error
# LPCN threw an error
# REV threw an error
# CLSD threw an error
# OVID threw an error
# MIRM threw an error
# GLYC threw an error
# TUSK threw an error
# EARN threw an error
# XERS threw an error
# SPRO threw an error
# MLP threw an error
# ALNA threw an error
# LQDA threw an error
# EKSO threw an error
# XGN threw an error
# SLDB threw an error
# EIGR threw an error
# ETON threw an error
# PAVM threw an error
# DMAC threw an error
# CHMI threw an error
# IDN threw an error
# FVE threw an error
# AGRX threw an error
# KIN threw an error
# AEYE threw an error
# WATT threw an error
# CABA threw an error
# LNSR threw an error
# AGLE threw an error
# FRD threw an error
# LJPC threw an error
# SFE threw an error
# MITT threw an error
# WPG threw an error
# LFT threw an error
# BCLI threw an error
# CSLT threw an error
# APLT threw an error
# CALA threw an error
# DJCO threw an error
# EYEN threw an error
# FULC threw an error
# TFFP threw an error
# ISR threw an error
# SRAX threw an error
# CASI threw an error
# CTIC threw an error
# EYES threw an error
# APTX threw an error
# TRVN threw an error
# REFR threw an error
# OTIC threw an error
# KLDO threw an error
# TELA threw an error
# CFRX threw an error
# SELF threw an error
# NERV threw an error
# SLGG threw an error
# ABEO threw an error
# GTIM threw an error
# ODT threw an error
# ATXI threw an error
# AQST threw an error
# TRMT threw an error
# MSVB threw an error
# ARDS threw an error
# CYCN threw an error
# GRTX threw an error
# HSDT threw an error
# STSA threw an error
# PANL threw an error
# IZEA threw an error
# EQ threw an error
# INMB threw an error
# JILL threw an error
# APRE threw an error
# ADMA threw an error
# NTIP threw an error
# AVCO threw an error
# SUNW threw an error
# TTOO threw an error
# NOVN threw an error
# EVFM threw an error
# MBRX threw an error
# NMTR threw an error
# RDVT threw an error
# VABK threw an error
# CDTX threw an error
# BLCM threw an error
# VTVT threw an error
# VERB threw an error
# SOLY threw an error
# AZRX threw an error
# AE threw an error
# SSBI threw an error
# LRMR threw an error
# EAST threw an error
# SCPH threw an error
# XFOR threw an error
# IDRA threw an error
# CLIR threw an error
# MOTS threw an error
# TRVI threw an error
# IPWR threw an error
# NNVC threw an error
# ADMP threw an error
# ATNM threw an error
# PZG threw an error
# AGE threw an error
# ARAV threw an error
# ESBK threw an error
# REED threw an error
# ONCS threw an error
# VCNX threw an error
# VIRX threw an error
# CAPR threw an error
# APDN threw an error
# PLXP threw an error
# CBLI threw an error
# GNCA threw an error
# TCON threw an error
# IMUX threw an error
# NSEC threw an error
# CVR threw an error
# MAYS threw an error
# CKX threw an error
# CIX threw an error
# CRVS threw an error
# NBSE threw an error
# BXRX threw an error
# YMTX threw an error
# CEI threw an error
# MYMD threw an error
# POAI threw an error
# VISL threw an error
# NVIV threw an error
# PULM threw an error
# PHIO threw an error
# SINT threw an error
# PSTV threw an error
# ARMP threw an error
# SEEL threw an error
# NURO threw an error
# AIKI threw an error
# CLRB threw an error
# VRDN threw an error
# MBOT threw an error
# TTNP threw an error
# HEPA threw an error
# ABIO threw an error
# ELDN threw an error
# EYEG threw an error
# ZSAN threw an error
# SEEL threw an error
# MDVL threw an error
# CLSN threw an error
# NETE threw an error
# SYN threw an error
# OGEN threw an error
# SLNO threw an error
# AEMD threw an error
# AIM threw an error
# DARE threw an error
# SLRX threw an error
# ACER threw an error
# TENX threw an error
# OCUP threw an error
# BPTH threw an error
# SYBX threw an error
# PDSB threw an error
# SVRA threw an error
# BRN threw an error
# IOR threw an error
# BBI threw an error
# AIII threw an error
# DGLY threw an error
# TARA threw an error
# CATB threw an error
# HBB threw an error
# HOTH threw an error
# WWR threw an error
# LIFE threw an error
# THMO threw an error
# HSTO threw an error
# PALI threw an error

# %%
# 650 "bad" tickers didn't make the cut
len(bad_tickers)
# Out:
# 650

# %%
# here are all the tickers that made it through
len(full_df_dict.keys())
# Out:
# 2889

# %%
# transforming the dictionary values (which are the combined financial DataFrames) into a list
full_df_list = [full_df_dict[ticker] for ticker in full_df_dict.keys()]

# %%
combo_df = pd.concat(full_df_list, axis=0)
combo_df.fillna(0,inplace=True)

# %%
combo_df = pd.get_dummies(combo_df, columns=['Ticker'])
combo_df.head()
# Out:
#                  Revenue  Gross Profit  Operating Income  \
# 2021-03-31  3.252080e+11  1.266010e+11      8.890300e+10
# 2020-12-31  2.939710e+11  1.137350e+11      7.425300e+10
# 2020-09-30  2.742470e+11  1.042750e+11      6.628800e+10
# 2020-06-30  2.736210e+11  1.039940e+11      6.713800e+10
# 2020-03-31  2.680150e+11  1.021730e+11      6.559100e+10
#
#             Income Tax Provision  Net Income Common  Total Assets  \
# 2021-03-31          1.331700e+10       7.631100e+10  3.371580e+11
# 2020-12-31          1.082200e+10       6.393000e+10  3.540540e+11
# 2020-09-30          9.680000e+09       5.741100e+10  3.238880e+11
# 2020-06-30          9.893000e+09       5.842400e+10  3.173440e+11
# 2020-03-31          9.876000e+09       5.721500e+10  3.204000e+11
#
#             Total current assets  Total liabilities  \
# 2021-03-31          1.214650e+11       2.679800e+11
# 2020-12-31          1.541060e+11       2.878300e+11
# 2020-09-30          1.437130e+11       2.585490e+11
# 2020-06-30          1.400650e+11       2.450620e+11
# 2020-03-31          1.437530e+11       2.419750e+11
#
#             Total current liabilities  Shareholders Equity (Total)  ...  \
# 2021-03-31               1.063850e+11                 6.917800e+10  ...
# 2020-12-31               1.325070e+11                 6.622400e+10  ...
# 2020-09-30               1.053920e+11                 6.533900e+10  ...
# 2020-06-30               9.531800e+10                 7.228200e+10  ...
# 2020-03-31               9.609400e+10                 7.842500e+10  ...
#
#             Ticker_ZIXI  Ticker_ZM  Ticker_ZNGA  Ticker_ZS  Ticker_ZTS  \
# 2021-03-31            0          0            0          0           0
# 2020-12-31            0          0            0          0           0
# 2020-09-30            0          0            0          0           0
# 2020-06-30            0          0            0          0           0
# 2020-03-31            0          0            0          0           0
#
#             Ticker_ZUMZ  Ticker_ZUO  Ticker_ZVO  Ticker_ZYNE  Ticker_ZYXI
# 2021-03-31            0           0           0            0            0
# 2020-12-31            0           0           0            0            0
# 2020-09-30            0           0           0            0            0
# 2020-06-30            0           0           0            0            0
# 2020-03-31            0           0           0            0            0
#
# [5 rows x 2904 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# %%
sc = StandardScaler()
X_train_k = sc.fit_transform(combo_df)

# %%
km = KMeans(n_clusters=6)
km.fit(X_train_k)
# Out:
# KMeans(n_clusters=6)

# %%
km.labels_
# Out:
# array([4, 4, 4, ..., 3, 3, 3])

# %%
combo_df['cluster'] = km.labels_

# %%
km.cluster_centers_
# Out:
# array([[-0.08849922, -0.09151312, -0.08046314, ..., -0.01932926,
#         -0.01666715, -0.0195756 ],
#        [ 0.46214847,  0.63145682,  0.5493718 , ..., -0.01932926,
#         -0.01666715, -0.0195756 ],
#        [ 3.13531233,  2.92875445,  2.48441723, ..., -0.01932926,
#         -0.01666715, -0.0195756 ],
#        [-0.23542384, -0.25499654, -0.21653348, ..., -0.01932926,
#          0.02412681,  0.02833699],
#        [ 8.33852621, 10.43007312,  9.68878419, ..., -0.01932926,
#         -0.01666715, -0.0195756 ],
#        [-0.13295563, -0.16673909, -0.15730667, ...,  0.05362743,
#         -0.01666715, -0.0195756 ]])

# %%
centroids = pd.DataFrame(
    sc.inverse_transform(km.cluster_centers_),
    columns = [combo_df.columns[:-1]]
)

# %%
plt.figure(figsize=(10,25));

## Plot scatter by cluster / color, and centroids
colors = ["red", "green", "blue",'yellow','orange','gray']
combo_df['color'] = combo_df['cluster'].map(lambda p: colors[p])

ax = combo_df.plot(    
    kind="scatter", 
    x="Total Assets", y="Total liabilities",
    figsize=(12,12),
    c = combo_df['color'], s=1
)

#plt.xlim(0,5E11)
#plt.ylim(0,5E11)


# centroids.plot(
#     kind="scatter", 
#     x="Gross Profit", y="Net Income Common", 
#     marker="*", c=["red", "green", "blue",'yellow','orange','black'], s=1000,
#     ax=ax
# )

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
# how close can I 'predict' revenues?

X = combo_df.drop(columns=['Revenue','color'])
y = combo_df['Revenue']

X_train, X_test, y_train, y_test = train_test_split(X,y)

sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
rf = RandomForestRegressor()

rf.fit(X_train_sc,y_train)
# Out:
# RandomForestRegressor()

# %%
print(f"Training score: {rf.score(X_train_sc,y_train)}")
print(f"Testing score: {rf.score(X_test_sc,y_test)}")
# Out:
# Training score: 0.9985566025667909
# Testing score: 0.9909029710569122

# %%
y_preds = rf.predict(X_test_sc)

# %%
from sklearn.metrics import mean_squared_error

print(f"RMSE of {round(np.sqrt(mean_squared_error(y_test,rf.predict(X_test_sc)))/1000000000, 2)} billion")
# Out:
# RMSE of 1.86 billion

# %%
pred_df = pd.DataFrame([y_preds,y_test]).T
pred_df
# Out:
#                   0             1
# 0      1.263602e+09  1.253730e+09
# 1      6.216055e+10  6.501700e+10
# 2      9.959257e+08  5.577370e+08
# 3      2.279080e+08  1.959090e+08
# 4      1.799427e+09  1.823090e+09
# ...             ...           ...
# 26101  2.406877e+07  1.337770e+07
# 26102  6.144359e+07  1.976630e+08
# 26103  1.070157e+08  1.043880e+08
# 26104  7.256969e+07  6.413380e+07
# 26105  4.730443e+09  4.603541e+09
#
# [26106 rows x 2 columns]

# %%
# Out:
# -inf

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# # DO NOT CALL THIS FUNCTION

# %% [markdown]
# ### (unless it's on purpose, of course)

# %%
#code to pull data in bulk
def bulk_stockrow_puller():
    ticker_list = stock_list['Ticker']
    bad_list = []

    for ticker in ticker_list:
        try:
            url_inc=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=T&section=Income%20Statement&sort=desc'
            response_inc = requests.get(url_inc)
            with open(os.path.join("Income", f"{ticker}_inc.xlsx"), 'wb') as f:
                f.write(response_inc.content)

            url_bal=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=Q&section=Balance%20Sheet&sort=desc'    
            response_bal = requests.get(url_bal)
            with open(os.path.join("BalanceSheet", f"{ticker}_bal.xlsx"), 'wb') as f:
                f.write(response_bal.content)

            url_cfl=f'https://stockrow.com/api/companies/{ticker}/financials.xlsx?dimension=T&section=Cash%20Flow&sort=desc'
            response_cfl = requests.get(url_cfl)
            with open(os.path.join("CashFlow", f"{ticker}_cashflow.xlsx"), 'wb') as f:
                f.write(response_cfl.content)
            time.sleep(0.25)
        except:
            print(f"{ticker} is bad")
            bad_list.append(ticker)

# %%
bulk_stockrow_puller()
